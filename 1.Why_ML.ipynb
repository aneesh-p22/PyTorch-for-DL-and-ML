# %% [markdown]
# It gets cumbersome to write out many rules to reproduce an output
#
# It is hard to think up all the rules for a complex problem yourself
#
# Google's ML rule (rule 1 of Google's ML handbook): "If you can build a simple rule-based system that doesn't require ML, do that"
