# %% [markdown]
# Machine Learning is turning things (data) into numbers and finding patterns in those numbers
#
# DL is a subset of ML which is a subset of AI
#
# Patterns are found through ML or DL algorithms through code and maths
#
# Traditional programming: given the inputs and the rules, give an output
#
# Machine learning: given the inputs and output, figure out the rules
